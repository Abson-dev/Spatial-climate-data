# %%
#Importing the necessary libraries
import numpy as np
import glob
from netCDF4 import Dataset
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
w = glob.glob(r"data\2023_WindSpeed\*.nc")
#print(w)

# %%
import xarray as xr
WindSpeed_data = xr.open_mfdataset(w)

# %%
print(WindSpeed_data)
# Out:
# <xarray.Dataset>
# Dimensions:              (lat: 300, lon: 520, time: 365)
# Coordinates:
#   * lat                  (lat) float64 29.9 29.8 29.7 29.6 ... 0.2 0.1 5.116e-12
#   * lon                  (lon) float64 -25.9 -25.8 -25.7 ... 25.8 25.9 26.0
#   * time                 (time) datetime64[ns] 2023-01-01 ... 2023-12-31
# Data variables:
#     Wind_Speed_10m_Mean  (time, lat, lon) float32 dask.array<chunksize=(1, 300, 520), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.7

# %%
WindSpeed_data.Wind_Speed_10m_Mean.isel(time=0).plot()

# %%
import rioxarray

WindSpeed_data.rio.set_spatial_dims(x_dim="lon", y_dim="lat", inplace=True)
WindSpeed_data.rio.write_crs("epsg:4326", inplace=True)
# Out:
# <xarray.Dataset>
# Dimensions:              (lat: 300, lon: 520, time: 365)
# Coordinates:
#   * lat                  (lat) float64 29.9 29.8 29.7 29.6 ... 0.2 0.1 5.116e-12
#   * lon                  (lon) float64 -25.9 -25.8 -25.7 ... 25.8 25.9 26.0
#   * time                 (time) datetime64[ns] 2023-01-01 ... 2023-12-31
#     spatial_ref          int32 0
# Data variables:
#     Wind_Speed_10m_Mean  (time, lat, lon) float32 dask.array<chunksize=(1, 300, 520), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.7

# %%
import geopandas
G5_Sahel = geopandas.read_file("data\G5_Sahel_adm2N\G5_Sahel_adm2N.shp", crs="epsg:4326")

# %%
G5_Sahel.head()
# Out:
#    OBJECTID    ADMIN0NAME ADMIN0PCOD         ADMIN1NAME ADMIN2NAME ADMIN1PCOD  \
# 0         1  Burkina Faso         BF  Boucle du Mouhoun       Bale       BF46
# 1         2  Burkina Faso         BF  Boucle du Mouhoun      Banwa       BF46
# 2         3  Burkina Faso         BF  Boucle du Mouhoun      Kossi       BF46
# 3         4  Burkina Faso         BF  Boucle du Mouhoun    Mouhoun       BF46
# 4         5  Burkina Faso         BF  Boucle du Mouhoun     Nayala       BF46
#
#   ADMIN2PCOD  INITIAL  Shape_Leng  Shape_Area  \
# 0     BF4601       49    4.830069    0.376722
# 1     BF4602       66    5.015746    0.490583
# 2     BF4603       90    4.115810    0.622852
# 3     BF4604       67    5.523416    0.571324
# 4     BF4605       76    2.757532    0.309684
#
#                                             geometry
# 0  POLYGON ((-3.20303 12.10678, -3.20041 12.10642...
# 1  POLYGON ((-4.35251 12.72334, -4.33422 12.70470...
# 2  POLYGON ((-3.96085 13.38282, -3.94660 13.37672...
# 3  POLYGON ((-3.44075 12.74873, -3.43919 12.74697...
# 4  POLYGON ((-3.19718 12.98010, -3.19483 12.97864...

# %%
clipped = WindSpeed_data.rio.clip(G5_Sahel.geometry, G5_Sahel.crs, drop=True)

# %%
import matplotlib.pyplot as plt
ax=G5_Sahel.plot(facecolor='none',edgecolor='black')
sahel=clipped.Wind_Speed_10m_Mean.isel(time=0).plot(ax=ax,zorder=-1)

# %%
#pip install xagg
import xagg as xa

# %%
# Get overlap between pixels and polygons
weightmap = xa.pixel_overlaps(WindSpeed_data, G5_Sahel, subset_bbox=False)
# Out:
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!

# %%
aggregated = xa.aggregate(WindSpeed_data, weightmap)
# Out:
# aggregating Wind_Speed_10m_Mean...
# all variables aggregated to polygons!

# %%
ds = aggregated.to_dataset()
# Drop columns multiple column

# %%
ds.head()
# Out:
# <xarray.Dataset>
# Dimensions:              (poly_idx: 5, time: 5)
# Coordinates:
#   * poly_idx             (poly_idx) int32 0 1 2 3 4
#   * time                 (time) datetime64[ns] 2023-01-01 ... 2023-01-05
# Data variables:
#     OBJECTID             (poly_idx) int64 1 2 3 4 5
#     ADMIN0NAME           (poly_idx) object 'Burkina Faso' ... 'Burkina Faso'
#     ADMIN0PCOD           (poly_idx) object 'BF' 'BF' 'BF' 'BF' 'BF'
#     ADMIN1NAME           (poly_idx) object 'Boucle du Mouhoun' ... 'Boucle du...
#     ADMIN2NAME           (poly_idx) object 'Bale' 'Banwa' ... 'Mouhoun' 'Nayala'
#     ADMIN1PCOD           (poly_idx) object 'BF46' 'BF46' 'BF46' 'BF46' 'BF46'
#     ADMIN2PCOD           (poly_idx) object 'BF4601' 'BF4602' ... 'BF4605'
#     INITIAL              (poly_idx) int64 49 66 90 67 76
#     Shape_Leng           (poly_idx) float64 4.83 5.016 4.116 5.523 2.758
#     Shape_Area           (poly_idx) float64 0.3767 0.4906 0.6229 0.5713 0.3097
#     Wind_Speed_10m_Mean  (poly_idx, time) float64 3.393 3.266 ... 2.65 2.581

# %%
# Example as a pandas dataframe
df_out = aggregated.to_dataframe()
df_out.head()
# Out:
#                      OBJECTID    ADMIN0NAME ADMIN0PCOD         ADMIN1NAME  \
# poly_idx time
# 0        2023-01-01         1  Burkina Faso         BF  Boucle du Mouhoun
#          2023-01-02         1  Burkina Faso         BF  Boucle du Mouhoun
#          2023-01-03         1  Burkina Faso         BF  Boucle du Mouhoun
#          2023-01-04         1  Burkina Faso         BF  Boucle du Mouhoun
#          2023-01-05         1  Burkina Faso         BF  Boucle du Mouhoun
#
#                     ADMIN2NAME ADMIN1PCOD ADMIN2PCOD  INITIAL  Shape_Leng  \
# poly_idx time
# 0        2023-01-01       Bale       BF46     BF4601       49    4.830069
#          2023-01-02       Bale       BF46     BF4601       49    4.830069
#          2023-01-03       Bale       BF46     BF4601       49    4.830069
#          2023-01-04       Bale       BF46     BF4601       49    4.830069
#          2023-01-05       Bale       BF46     BF4601       49    4.830069
#
#                      Shape_Area  Wind_Speed_10m_Mean
# poly_idx time
# 0        2023-01-01    0.376722             3.392818
#          2023-01-02    0.376722             3.265859
#          2023-01-03    0.376722             3.103138
#          2023-01-04    0.376722             2.686595
#          2023-01-05    0.376722             2.561521

# %%
ds.to_dataframe().to_csv("2023_G5_Sahel_Wind_Speed_10m_Mean.csv")
